# %%
import pandas as pd
import numpy as np
import thinkplot
import thinkstats2
from statistics import mean, median, mode, stdev

dfheart = pd.read_csv("heart_data.csv")

# %%
dfheart
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# age: age in years
#
# sex: sex [1 = male, 0 = female]
#
# cp: chest pain type [Value 0: typical angina, Value 1: atypical angina, Value 2: non-anginal pain, Value 3: asymptomatic]
#
# trestbps: resting blood pressure (in mm Hg on admission to the hospital)
#
# chol: serum cholestoral in mg/dl
#
# fbs: (fasting blood sugar > 120 mg/dl) [1 = true; 0 = false]
#
# restecg: resting electrocardiographic results [Value 0: normal, Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria]
#
# thalach: maximum heart rate achieved
#
# exang: exercise induced angina [1 = yes, 0 = no]
#
# oldpeak = ST depression induced by exercise relative to rest
#
# slope: the slope of the peak exercise ST segment [Value 0: upsloping, Value 1: flat, Value 2: downsloping]
#
# ca: number of major vessels (0-3) colored by flourosopy
#
# thal: [0 = error (in the original dataset 0 maps to NaN's), 1 = fixed defect, 2 = normal, 3 = reversable defect]
#
# target (the lable): [0 = no disease, 1 = disease]

# %%
hist_a = thinkstats2.Hist(dfheart['age'], label = "age")
thinkplot.Hist(hist_a)
thinkplot.Show(xlabel = 'age', ylabel = 'count')
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
hist_c = thinkstats2.Hist(dfheart['chol'], label = "chol")
thinkplot.Hist(hist_c)
thinkplot.Show(xlabel = 'chol', ylabel = 'count')
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
hist_t = thinkstats2.Hist(dfheart['trestbps'], label = "Resting Blood Pressure")
thinkplot.Hist(hist_t)
thinkplot.Show(xlabel = 'trestbps', ylabel = 'count')
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
hist_h = thinkstats2.Hist(dfheart['thalach'], label = "Max Heart Rate")
thinkplot.Hist(hist_h)
thinkplot.Show(xlabel = 'thalach', ylabel = 'count')
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
hist_f = thinkstats2.Hist(dfheart['fbs'], label = "Fasting Blood Sugar > 120")
thinkplot.Hist(hist_f)
thinkplot.Show(xlabel = 'fbs', ylabel = 'count')
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
hist_s = thinkstats2.Hist(dfheart['sex'], label = "sex")
thinkplot.Hist(hist_s)
thinkplot.Show(xlabel = 'sex', ylabel = 'count')
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
hist_g = thinkstats2.Hist(dfheart['target'], label = "Heart Disease")
thinkplot.Hist(hist_g)
thinkplot.Show(xlabel = 'target', ylabel = 'count')
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %% [markdown]
# identify any outliers and explain the reasoning for them being outliers and how you believe they should be handled (Chapter 2).

# %% [markdown]
# I thought cholesterol might have some outliers due to how the plot looked. However, I ran the below code and it's all within normal range. No outliers apparent on any of the rest of the data.

# %%
#checking cholesterol for outliers but there don't appear to be any. 
for chol, freq in hist_c.Smallest(5):
    print(chol, freq)
for chol, freq in hist_c.Largest(5):
    print(chol, freq)
# Out:
# 126 1
# 131 1
# 141 1
# 149 2
# 157 1
# 564 1
# 417 1
# 409 1
# 407 1
# 394 1

# %% [markdown]
# Include the other descriptive characteristics about the variables: Mean, Mode, Spread, and Tails (Chapter 2).

# %%
dfheart.chol.mean()
# Out:
# 246.26402640264027

# %%
dfheart.chol.mode()
# Out:
# 0    197
# 1    204
# 2    234
# Name: chol, dtype: int64

# %%
dfheart.chol.std()
# Out:
# 51.83075098793003

# %%
dfheart.chol.var()
# Out:
# 2686.42674797281

# %%
dfheart.age.mean()
# Out:
# 54.366336633663366

# %%
dfheart.age.mode()
# Out:
# 0    58
# Name: age, dtype: int64

# %%
dfheart.age.std()
# Out:
# 9.082100989837857

# %%
dfheart.age.var()
# Out:
# 82.48455838961378

# %%
dfheart.trestbps.mean()
# Out:
# 131.62376237623764

# %%
dfheart.trestbps.mode()
# Out:
# 0    120
# Name: trestbps, dtype: int64

# %%
dfheart.trestbps.std()
# Out:
# 17.5381428135171

# %%
dfheart.trestbps.var()
# Out:
# 307.58645334732154

# %%
dfheart.thalach.mean()
# Out:
# 149.64686468646866

# %%
dfheart.thalach.mode()
# Out:
# 0    162
# Name: thalach, dtype: int64

# %%
dfheart.thalach.std()
# Out:
# 22.905161114914094

# %%
dfheart.thalach.var()
# Out:
# 524.6464057001726

# %% [markdown]
# Using pg. 29 of your text as an example, compare two scenarios in your data using a PMF. Reminder, this isn’t comparing two variables against each other – it is the same variable, but a different scenario. Almost like a filter. The example in the book is first babies compared to all other babies, it is still the same variable, but breaking the data out based on criteria we are exploring (Chapter 3).

# %%
#in this section I'll be comparing those with heart disease 
#and their cholesterol levels with those without heart disease and their cholesterol levels

target_1 = dfheart[dfheart.target == 0].astype(float)
target_2 = dfheart[dfheart.target == 1].astype(float)

# %%
hist_1 = thinkstats2.Hist(target_1.chol, label = "people without heart disease")
thinkplot.Hist(hist_1)
thinkplot.Config(xlabel = "cholesterol", ylabel = "cont")
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
target_1.chol.mean()
# Out:
# 251.08695652173913

# %%
hist_2 = thinkstats2.Hist(target_2.chol, label = "people with heart disease")
thinkplot.Hist(hist_2)
thinkplot.Config(xlabel = "cholesterol", ylabel = "cont")
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
target_2.chol.mean()
# Out:
# 242.23030303030302

# %%
first_pmf = thinkstats2.Pmf(target_1.chol, label = "people without heart disease")
second_pmf = thinkstats2.Pmf(target_2.chol, label = "people with heart disease")

thinkplot.Pmf(first_pmf)
thinkplot.Config(xlabel = "cholesterol", ylabel = "pmf")
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
thinkplot.Pmf(second_pmf)
thinkplot.Config(xlabel = "cholesterol", ylabel = "pmf")

# %%
width = 0.45
axis = [27, 46, 0, 0.6]
thinkplot.PrePlot(2, cols=2)
thinkplot.Hist(first_pmf, align="right", width=width)
thinkplot.Hist(second_pmf, align="left", width=width)
thinkplot.Config(xlabel="cholesterol", ylabel="PMF", axis=axis)

thinkplot.PrePlot(2)
thinkplot.SubPlot(2)
thinkplot.Pmfs([first_pmf, second_pmf])
thinkplot.Config(xlabel="cholesterol", axis=axis)


#not sure why this graph is blank

# %% [markdown]
# Create 1 CDF with one of your variables, using page 41-44 as your guide, what does this tell you about your variable and how does it address the question you are trying to answer (Chapter 4).

# %%
cdf = thinkstats2.Cdf(target_1.trestbps, label='people without heart disease')
thinkplot.Cdf(cdf)
thinkplot.Config(xlabel='resting blood pressure', ylabel='CDF', loc='upper left')
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
cdf = thinkstats2.Cdf(target_2.trestbps, label='people with heart disease')
thinkplot.Cdf(cdf)
thinkplot.Config(xlabel='resting blood pressure', ylabel='CDF', loc='upper left')
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %% [markdown]
# From these two graphs, we can see that people without heart disease have, overall, a higher resting blood pressure, when first admitted to a hospital.

# %% [markdown]
# Plot 1 analytical distribution and provide your analysis on how it applies to the dataset you have chosen (Chapter 5).

# %%
diffs = target_1.fbs.diff()
cdf = thinkstats2.Cdf(diffs, label="actual")

thinkplot.Cdf(cdf)
thinkplot.Config(xlabel="fasting blood sugar", ylabel="CDF")
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
thinkplot.Cdf(cdf, complement=True)
thinkplot.Config(
    xlabel="fasting blood sugar",
    ylabel="CCDF",
    yscale="log",
    loc="upper right",
)

# %%
diffs = target_2.fbs.diff()
cdf = thinkstats2.Cdf(diffs, label="actual")

thinkplot.Cdf(cdf)
thinkplot.Config(xlabel="fasting blood sugar", ylabel="CDF")
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
hist_c = thinkstats2.Hist(target_1.fbs, label = "fasting blood sugar")
thinkplot.Hist(hist_c)
thinkplot.Show(xlabel = 'fbs', ylabel = 'count')
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
hist_c = thinkstats2.Hist(target_2.fbs, label = "fasting blood sugar")
thinkplot.Hist(hist_c)
thinkplot.Show(xlabel = 'fasting blood sugar', ylabel = 'count')
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %% [raw]
# Create two scatter plots comparing two variables and provide your analysis on correlation and causation. Remember, covariance, Pearson’s correlation, and Non-Linear Relationships should also be considered during your analysis (Chapter 7).

# %%
age, target = dfheart['age'], dfheart['target']

thinkplot.Scatter(age, target, alpha=1)
thinkplot.Config(xlabel='age',
                 ylabel='heart disease',
                 axis=[30, 80, 0, 1],
                 legend=False)

# %%
def Jitter(values, jitter=0.5):
    n = len(values)
    return np.random.normal(0, jitter, n) + values


age_1 = Jitter(age, 1.0)
target_1 = Jitter(target, 0.2)

thinkplot.Scatter(age_1, target_1, alpha=1)
thinkplot.Config(xlabel='age',
                 ylabel='heart disease',
                 axis=[30, 80, 0, 1],
                 legend=False)

# %%
thinkplot.Scatter(age_1, target_1, alpha=0.1, s=10)
thinkplot.Config(xlabel='age',
                 ylabel='heart disease',
                 axis=[20, 80, 0, 1],
                 legend=False)

# %%
thinkstats2.Corr(age,target)
# Out:
# -0.22543871587483727

# %%
thinkstats2.SpearmanCorr(age,target)
# Out:
# -0.2384000706816547

# %% [markdown]
# according to the above data, in this dataset, there is not a correlation between the people with and without heart disease and their age. Meaning that, from the people invertiewed, had similar ages in those with and without heart disease.

# %%
np.corrcoef(age, target)
# Out:
# array([[ 1.        , -0.22543872],
#        [-0.22543872,  1.        ]])

# %%
thinkstats2.Cov(age,target)
# Out:
# -1.0179720942391268

# %% [markdown]
# Conduct a test on your hypothesis using one of the methods covered in Chapter 9.

# %%
class DiffMeansPermute(thinkstats2.HypothesisTest):

    def TestStatistic(self, data):
        group1, group2 = data
        test_stat = abs(group1.mean() - group2.mean())
        return test_stat

    def MakeModel(self):
        group1, group2 = self.data
        self.n, self.m = len(group1), len(group2)
        self.pool = np.hstack((group1, group2))

    def RunModel(self):
        np.random.shuffle(self.pool)
        data = self.pool[:self.n], self.pool[self.n:]
        return data

# %%
target_1 = dfheart[dfheart.target == 0].astype(float)
target_2 = dfheart[dfheart.target == 1].astype(float)


data = target_1.thalach, target_2.thalach
ht = DiffMeansPermute(data)
pvalue = ht.PValue()
pvalue
# Out:
# 0.0

# %%
ht.PlotCdf()
thinkplot.Config(xlabel='max heart rate',
                   ylabel='CDF')

# %%
class DiffMeansOneSided(DiffMeansPermute):

    def TestStatistic(self, data):
        group1, group2 = data
        test_stat = group1.mean() - group2.mean()
        return test_stat

# %%
ht = DiffMeansOneSided(data)
pvalue = ht.PValue()
pvalue
# Out:
# 1.0

# %%
class DiffStdPermute(DiffMeansPermute):

    def TestStatistic(self, data):
        group1, group2 = data
        test_stat = group1.std() - group2.std()
        return test_stat

# %%
ht = DiffStdPermute(data)
pvalue = ht.PValue()
pvalue
#not statistically significant
# Out:
# 0.032

# %%
class CorrelationPermute(thinkstats2.HypothesisTest):

    def TestStatistic(self, data):
        xs, ys = data
        test_stat = abs(thinkstats2.Corr(xs, ys))
        return test_stat

    def RunModel(self):
        xs, ys = self.data
        xs = np.random.permutation(xs)
        return xs, ys

# %%
cleaned = dfheart.dropna(subset=['target', 'thalach'])
data = cleaned.target.values, cleaned.thalach.values
ht = CorrelationPermute(data)
pvalue = ht.PValue()
pvalue
# Out:
# 0.0

# %%
ht.actual, ht.MaxTestStat()
# Out:
# (0.42174093381067457, 0.1977231634347047)

# %%
class MaxHeart(thinkstats2.HypothesisTest):

    def MakeModel(self):
        firsts, others = self.data
        self.n = len(firsts)
        self.pool = np.hstack((firsts, others))

        pmf = thinkstats2.Pmf(self.pool)
        self.values = range(35, 44)
        self.expected_probs = np.array(pmf.Probs(self.values))

    def RunModel(self):
        np.random.shuffle(self.pool)
        data = self.pool[:self.n], self.pool[self.n:]
        return data
    
    def TestStatistic(self, data):
        firsts, others = data
        stat = self.ChiSquared(firsts) + self.ChiSquared(others)
        return stat

    def ChiSquared(self, lengths):
        hist = thinkstats2.Hist(lengths)
        observed = np.array(hist.Freqs(self.values))
        expected = self.expected_probs * len(lengths)
        stat = sum((observed - expected)**2 / expected)
        return stat

# %%
data = target_1.thalach.values, target_2.thalach.values
ht = MaxHeart(data)
p_value = ht.PValue()
print('p-value =', p_value)
print('actual =', ht.actual)
print('ts max =', ht.MaxTestStat())
# Out:
# p-value = 0.0
# actual = nan
# ts max = nan
# C:\Users\brean\AppData\Local\Temp\ipykernel_28388\2028762895.py:26: RuntimeWarning: invalid value encountered in divide
#   stat = sum((observed - expected)**2 / expected)

# %%
class DiffMeansResample(DiffMeansPermute):
    
    def RunModel(self):
        group1 = np.random.choice(self.pool, self.n, replace=True)
        group2 = np.random.choice(self.pool, self.m, replace=True)
        return group1, group2

# %%
def RunResampleTest(target_1, target_2):

    data = target_1.thalach.values, target_2.thalach.values
    ht = DiffMeansResample(data)
    p_value = ht.PValue(iters=10000)
    print('\ndiff means resample max heart rate')
    print('p-value =', p_value)
    print('actual =', ht.actual)
    print('ts max =', ht.MaxTestStat())

    data = (target_1.age.dropna().values,
            target_2.age.dropna().values)
    ht = DiffMeansPermute(data)
    p_value = ht.PValue(iters=10000)
    print('\ndiff means resample age')
    print('p-value =', p_value)
    print('actual =', ht.actual)
    print('ts max =', ht.MaxTestStat())

# %%
RunResampleTest(target_1,target_2)
# Out:
# diff means resample max heart rate
# p-value = 0.0
# actual = 19.365217391304355
# ts max = 10.394993412384707
#
# diff means resample age
# p-value = 0.0
# actual = 4.1044795783926205
# ts max = 4.077865612648225

# %% [markdown]
# For this project, conduct a regression analysis on either one dependent and one explanatory variable, or multiple explanatory variables (Chapter 10 & 11).

# %%
from thinkstats2 import Mean, MeanVar, Var, Std, Cov

def LeastSquares(xs, ys):
    meanx, varx = MeanVar(xs)
    meany = Mean(ys)

    slope = Cov(xs, ys, meanx, meany) / varx
    inter = meany - slope * meanx

    return inter, slope

inter, slope = LeastSquares(dfheart['target'], dfheart['fbs'])
inter, slope
# Out:
# (0.15942028985507248, -0.020026350461133085)

# %%
inter + slope * 25
# Out:
# -0.3412384716732546

# %%
slope * 10
# Out:
# -0.20026350461133086

# %%
def FitLine(xs, inter, slope):
    fit_xs = np.sort(xs)
    fit_ys = inter + slope * fit_xs
    return fit_xs, fit_ys

# %%
fit_xs, fit_ys = FitLine(dfheart['fbs'], inter, slope)

# %%
thinkplot.Scatter(dfheart['target'], dfheart['fbs'], color='blue', alpha=0.1, s=10)
thinkplot.Plot(fit_xs, fit_ys, color='black', linewidth=3)
thinkplot.Plot(fit_xs, fit_ys, color='red', linewidth=2)
thinkplot.Config(xlabel="heart disease",
                 ylabel='fasting blood pressure',
                 axis=[0, 2, 0, 2],
                 legend=False)

# %%
def LeastSquares(xs, ys):
    meanx, varx = MeanVar(xs)
    meany = Mean(ys)

    slope = Cov(xs, ys, meanx, meany) / varx
    inter = meany - slope * meanx

    return inter, slope

inter, slope = LeastSquares(dfheart['target'], dfheart['trestbps'])
inter, slope
# Out:
# (134.3985507246377, -5.095520421607376)

# %%
def FitLine(xs, inter, slope):
    fit_xs = np.sort(xs)
    fit_ys = inter + slope * fit_xs
    return fit_xs, fit_ys

fit_xs, fit_ys = FitLine(dfheart['trestbps'], inter, slope)

# %%
thinkplot.Scatter(dfheart['target'], dfheart['trestbps'], color='blue', alpha=0.1, s=10)
thinkplot.Plot(fit_xs, fit_ys, color='black', linewidth=3)
thinkplot.Plot(fit_xs, fit_ys, color='red', linewidth=2)
thinkplot.Config(xlabel="heart disease",
                 ylabel='trestbps',
                 axis=[0, 2, 0, 200],
                 legend=False)

# %%
def LeastSquares(xs, ys):
    meanx, varx = MeanVar(xs)
    meany = Mean(ys)

    slope = Cov(xs, ys, meanx, meany) / varx
    inter = meany - slope * meanx

    return inter, slope

inter, slope = LeastSquares(dfheart['age'], dfheart['trestbps'])
inter, slope
# Out:
# (102.29610118508202, 0.5394452340751623)

# %%
def FitLine(xs, inter, slope):
    fit_xs = np.sort(xs)
    fit_ys = inter + slope * fit_xs
    return fit_xs, fit_ys

fit_xs, fit_ys = FitLine(dfheart['age'], inter, slope)

# %%
thinkplot.Scatter(dfheart['trestbps'], dfheart['age'], color='blue', alpha=0.1, s=10)
thinkplot.Plot(fit_xs, fit_ys, color='black', linewidth=3)
thinkplot.Plot(fit_xs, fit_ys, color='red', linewidth=2)
thinkplot.Config(xlabel="age",
                 ylabel='trestbps',
                 axis=[0, 80, 0, 150],
                 legend=False)
