# %%
import pandas as pd
import numpy as np
import thinkplot
import thinkstats2

df2019 = pd.read_csv("ACSST1Y2019.csv")
df2021 = pd.read_csv("ACSST1Y2021.csv")
df = pd.read_csv("raw_data.csv")
df
# Out:
#       iso_code     location        date  total_cases  total_deaths  \
# 0          AFG  Afghanistan  2019-12-31          0.0           0.0
# 1          AFG  Afghanistan  2020-01-01          0.0           0.0
# 2          AFG  Afghanistan  2020-01-02          0.0           0.0
# 3          AFG  Afghanistan  2020-01-03          0.0           0.0
# 4          AFG  Afghanistan  2020-01-04          0.0           0.0
# ...        ...          ...         ...          ...           ...
# 50413      ZWE     Zimbabwe  2020-10-15       8055.0         231.0
# 50414      ZWE     Zimbabwe  2020-10-16       8075.0         231.0
# 50415      ZWE     Zimbabwe  2020-10-17       8099.0         231.0
# 50416      ZWE     Zimbabwe  2020-10-18       8110.0         231.0
# 50417      ZWE     Zimbabwe  2020-10-19       8147.0         231.0
#
#        stringency_index  population  gdp_per_capita  human_development_index  \
# 0                  0.00    38928341        1803.987                    0.498
# ...

# %%
df['log_total_deaths'] = np.log(df['total_deaths']+1)

# %%
hist = thinkstats2.Hist(df.log_total_deaths,label="log_total_deaths")
thinkplot.Hist(hist)
thinkplot.Config(ylim=[0,100])
thinkplot.Show(xlabel = 'log_total_deaths', ylabel = 'count')
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
hist = thinkstats2.Hist(df.total_deaths,label="total_deaths")
thinkplot.Hist(hist)
thinkplot.Config(xlim=[-100,500])
thinkplot.Show(xlabel = 'total_deaths', ylabel = 'count')
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
hist = thinkstats2.Hist(df.stringency_index,label="stringency_index")
thinkplot.Hist(hist)
thinkplot.Show(xlabel = 'stringency_index', ylabel = 'count')
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
import math
hist = thinkstats2.Hist(df.location,label="location")
thinkplot.Hist(hist)
thinkplot.Show(xlabel = 'location', ylabel = 'count')
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
hist = thinkstats2.Hist(df.gdp_per_capita,label="gdp_per_capita")
thinkplot.Hist(hist)
thinkplot.Show(xlabel = 'gdp_per_capita', ylabel = 'count')
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
hist = thinkstats2.Hist(df.human_development_index,label="human_development_index")
thinkplot.Hist(hist)
thinkplot.Show(xlabel = 'human_development_index', ylabel = 'count')
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
df_numerical = df.select_dtypes(include=[np.number])

# Calculate the Z-score of each value
z_scores = (df_numerical-df_numerical.mean())/df_numerical.std()

# Remove outliers based on the Z-score method
df_numerical = df_numerical[(z_scores < 3).all(axis=1)]

# %%
df_numerical.nunique()
# Out:
# total_cases                16853
# total_deaths                5594
# stringency_index             161
# population                   149
# gdp_per_capita               149
# human_development_index      135
# Unnamed: 12                  149
# dtype: int64

# %%
hist = thinkstats2.Hist(df_numerical["total_cases"])
thinkplot.Hist(hist)
thinkplot.Show()
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())

# %%
# Plot histograms for each column
for column in df_numerical.columns:
    hist = thinkstats2.Hist(df_numerical[column])
    thinkplot.Hist(hist)
    thinkplot.Show()
# Out:
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())
# C:\Users\brean\OneDrive\Desktop\final project\Parker530Week12\Parker530Week12\thinkstats2.py:161: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   self.d.update(obj.value_counts().iteritems())
# ...

# %%
hist_df = df['total_deaths'].items()
hist = thinkstats2.Hist(hist_df)
thinkplot.Hist(hist)
thinkplot.Show(xlabel = 'total_deaths', ylabel = 'count')

# %%
hist = thinkstats2.Hist(df['iso_code'], label = "2")
thinkplot.Hist(hist)
thinkplot.Show(xlabel = 'iso_code', ylabel = 'total_cases')

# %%
hist = thinkstats2.Hist(df['location'], label = "2")
thinkplot.Hist(hist)
thinkplot.Show(xlabel = 'location', ylabel = 'total_cases')

# %%
hist = thinkstats2.Hist(df, label = "3")
thinkplot.Hist(hist)
thinkplot.Show(xlabel = 'location', ylabel = 'population')

# %%
hist = thinkstats2.Hist(df, label = "4")
thinkplot.Hist(hist)
thinkplot.Show(xlabel = 'location', ylabel = 'gpd_per_capita')

# %%
hist = thinkstats2.Hist(df, label = "5")
thinkplot.Hist(hist)
thinkplot.Show(xlabel = 'location', ylabel = 'stringency_index')
